# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/The-Data-Analyst-Course-Complete-Data-Analyst-Bootcamp-2023/blob/main/Example_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Packages

# %%
import numpy as np
import csv

# %% [markdown]
# Importing the Data

# %%
with open('Features.csv', 'r') as f:
    reader = csv.reader(f)
    for i, row in enumerate(reader):
        try:
            # process the row
            print(row)  # Example of processing the row
        except ValueError:
            # handle the error
           print(f"Error on line {i+1}")
# Out:
# ['id', 'name', 'duration', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'danceability']
# ['0VjIjW4GlUZAMYd2vXMi3b', 'Blinding Lights', '3.33', '0.73', '1', '-5.934', '1', '0.0598', '0.00146', '9.54e-05', '0.0897', '0.334', '171.005', '0.514']
# ['7qiZfU4dY1lWllzX7mPBI3', 'Shape of You', '3.9', '0.652', '1', '-3.183', '0', '0.0802', '0.581', '0.0', '0.0931', '0.931', '95.977', '0.825']
# ['2XU0oxnq2qxCpomAAuJY8K', 'Dance Monkey', '3.49', '0.588', '6', '-6.4', '0', '0.0924', '0.692', '0.000104', '0.149', '0.513', '98.027', '0.824']
# ['7qEHsqek33rTcFNT9PFqLf', 'Someone You Loved', '3.04', '0.405', '1', '-5.679', '1', '0.0319', '0.751', '0.0', '0.105', '0.446', '109.891', '0.501']
# ['0e7ipj03S05BNilyu5bRzt', 'Rockstar', '3.64', '0.52', '5', '-6.136', '0', '0.0712', '0.124', '7.01e-05', '0.131', '0.129', '159.801', '0.585']
# ...

# %%
import pandas as pd
raw_data = pd.read_csv('Features.csv')

# %%
raw_data
# Out:
#                         id               name  duration  energy  key  \
# 0   0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights      3.33   0.730    1
# 1   7qiZfU4dY1lWllzX7mPBI3       Shape of You      3.90   0.652    1
# 2   2XU0oxnq2qxCpomAAuJY8K       Dance Monkey      3.49   0.588    6
# 3   7qEHsqek33rTcFNT9PFqLf  Someone You Loved      3.04   0.405    1
# 4   0e7ipj03S05BNilyu5bRzt           Rockstar      3.64   0.520    5
# ..                     ...                ...       ...     ...  ...
# 95  5kqIPrATaCc2LqxVWzQGbk            7 Years      3.96   0.473   10
# 96  3AJwUDP919kvQ9QcozQPxg             Yellow      4.45   0.661   11
# 97  6UelLqGlWMcVH1E5c4H7lY              Sugar      2.90   0.816    0
# 98  6habFhsOp2NvshLv26DqMb          Despacito      3.82   0.797    2
# 99  6XdYD0hrNIOHb0emKC3l9U  Don't Stop Me Now      7.05   0.553    5
#
#     loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
type(raw_data)
# Out:
# pandas.core.frame.DataFrame

# %%
raw_data.shape
# Out:
# (100, 14)

# %%
raw_data.isnull()
# Out:
#        id   name  duration  energy    key  loudness   mode  speechiness  \
# 0   False  False     False   False  False     False  False        False
# 1   False  False     False   False  False     False  False        False
# 2   False  False     False   False  False     False  False        False
# 3   False  False     False   False  False     False  False        False
# 4   False  False     False   False  False     False  False        False
# ..    ...    ...       ...     ...    ...       ...    ...          ...
# 95  False  False     False   False  False     False  False        False
# 96  False  False     False   False  False     False  False        False
# 97  False  False     False   False  False     False  False        False
# 98  False  False     False   False  False     False  False        False
# 99  False  False     False   False  False     False  False        False
#
#     acousticness  instrumentalness  liveness  valence  tempo  danceability
# ...

# %%
raw_data['name']
# Out:
# 0       Blinding Lights
# 1          Shape of You
# 2          Dance Monkey
# 3     Someone You Loved
# 4              Rockstar
#             ...
# 95              7 Years
# 96               Yellow
# 97                Sugar
# 98            Despacito
# 99    Don't Stop Me Now
# Name: name, Length: 100, dtype: object

# %%
# with the same output but different way
raw_data.name
# Out:
# 0       Blinding Lights
# 1          Shape of You
# 2          Dance Monkey
# 3     Someone You Loved
# 4              Rockstar
#             ...
# 95              7 Years
# 96               Yellow
# 97                Sugar
# 98            Despacito
# 99    Don't Stop Me Now
# Name: name, Length: 100, dtype: object

# %%
raw_data['tempo'].max()
# Out:
# 186.003

# %%
df2 = raw_data.loc[raw_data['tempo'].idxmax()]
df2
# Out:
# id                  7MXVkk9YMctZqd1Srtv4MB
# name                               Starboy
# duration                              3.84
# energy                               0.587
# key                                      7
# loudness                            -7.015
# mode                                     1
# speechiness                          0.276
# acousticness                         0.141
# instrumentalness                  0.000006
# liveness                             0.137
# valence                              0.486
# tempo                              186.003
# danceability                         0.679
# Name: 14, dtype: object

# %%
raw_csv_data = pd.read_csv("Absenteeism-data.csv")

# %%
type(raw_csv_data)
# Out:
# pandas.core.frame.DataFrame

# %%
raw_csv_data
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
# copy initial data
df = raw_csv_data.copy()
df
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
