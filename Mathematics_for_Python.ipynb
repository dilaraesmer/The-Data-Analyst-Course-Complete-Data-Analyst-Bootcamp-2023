# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/The-Data-Analyst-Course-Complete-Data-Analyst-Bootcamp-2023/blob/main/Mathematics_for_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A matrix is a collection of numbers ordered in rows and columns.

# %% [markdown]
# ![Matrices-Example.png](data:image/png;base64,...)
#
# https://www.piqosity.com/2017/05/03/isee-math-review-matrices/

# %% [markdown]
# Import the relevant libraries

# %%
import numpy as np

# %% [markdown]
# Declaring scalars, vectors, and matrices

# %% [markdown]
# Scalars

# %%
s = 5

# %%
s
# Out:
# 5

# %% [markdown]
# Vectors

# %%
v = np.array([5, -2, 4])

# %%
v
# Out:
# array([ 5, -2,  4])

# %% [markdown]
# Matrices

# %%
m = np.array([[5, 12, 6], [-3, 0, 14]])

# %%
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %% [markdown]
# Data Types

# %% [markdown]
# type(a) returns the data type of a given variable

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray

# %%
s_array = np.array(5)
s_array
# Out:
# array(5)

# %%
type(s_array)
# Out:
# numpy.ndarray

# %% [markdown]
# Data shapes

# %% [markdown]
# shape returns the shape (dimensions) of a variable

# %%
m.shape
# Out:
# (2, 3)

# %%
v.shape
# Out:
# (3,)

# %%
# ERROR Because 0 dimensional objects don't have shape
s.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-01f5ed468f52> in <module>
#       1 # ERROR Because 0 dimensional objects don't have shape
# ----> 2 s.shape
#
# AttributeError: 'int' object has no attribute 'shape'

# %% [markdown]
# Creating a column vector

# %% [markdown]
# reshape gives an array a new shape, without changing its data

# %%
v.reshape(1,3)

# %%
v.reshape(3,1)

# %% [markdown]
# Creating a tensor

# %%
m1 = np.array([[5, 12, 6], [-3, 0, 14]])
m1
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m2 = np.array([[9,8,7], [1, 3, -5]])
m2
# Out:
# array([[ 9,  8,  7],
#        [ 1,  3, -5]])

# %% [markdown]
# Addition

# %%
m1 + m2
# Out:
# array([[14, 20, 13],
#        [-2,  3,  9]])

# %% [markdown]
# Subtraction

# %%
m1 - m2
# Out:
# array([[-4,  4, -1],
#        [-4, -3, 19]])

# %%
t = np.array([m1,m2])

# %%
t
# Out:
# array([[[ 5, 12,  6],
#         [-3,  0, 14]],
#
#        [[ 9,  8,  7],
#         [ 1,  3, -5]]])

# %% [markdown]
# Checking its shape

# %%
t.shape
# Out:
# (2, 2, 3)

# %% [markdown]
# Manually creating a tensor

# %%
t_manual = np.array([[[5,12,6], [-3,0,14]], [[9,8,7], [1,3,-5]]])

# %%
t_manual
# Out:
# array([[[ 5, 12,  6],
#         [-3,  0, 14]],
#
#        [[ 9,  8,  7],
#         [ 1,  3, -5]]])

# %% [markdown]
# Difference
#
# Example 1

# %%
m3 = np.array([[5,3], [-2,4]])
m4 = np.array([[7,-5], [3,8]])

# %%
m3
# Out:
# array([[ 5,  3],
#        [-2,  4]])

# %%
m4
# Out:
# array([[ 7, -5],
#        [ 3,  8]])

# %%
m3 - m4
# Out:
# array([[-2,  8],
#        [-5, -4]])

# %% [markdown]
# Adding vectors together

# %%
v1 = np.array([1,2,3,4,5])
v2 = np.array([5,4,3,2,1])

# %%
v1 + v2
# Out:
# array([6, 6, 6, 6, 6])

# %%
v1 - v2
# Out:
# array([-4, -2,  0,  2,  4])

# %%
np.array([v1,v2])
# Out:
# array([[1, 2, 3, 4, 5],
#        [5, 4, 3, 2, 1]])

# %% [markdown]
# Addition of scalars

# %%
5 + 5
# Out:
# 10

# %%
10 + 4
# Out:
# 14

# %% [markdown]
# Exceptions (adddition with a scalar)

# %%
m1
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m1 + 1
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
v1
# Out:
# array([1, 2, 3, 4, 5])

# %%
v1 + 1
# Out:
# array([2, 3, 4, 5, 6])

# %%
m1 + np.array([1])
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
v1 + np.array([1])
# Out:
# array([2, 3, 4, 5, 6])

# %% [markdown]
# Transposing matrices

# %%
A = np.array([[5,12,6], [-3,0,14]])
A
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %% [markdown]
# array.T returns the transpose of an array (matrix)

# %%
A.T
# Out:
# array([[ 5, -3],
#        [12,  0],
#        [ 6, 14]])

# %%
B = np.array([[5,3], [-2,4]])
B
# Out:
# array([[ 5,  3],
#        [-2,  4]])

# %%
B.T
# Out:
# array([[ 5, -2],
#        [ 3,  4]])

# %%
C = np.array([[4,-5], [8,12], [-2,-3], [19,0]])
C
# Out:
# array([[ 4, -5],
#        [ 8, 12],
#        [-2, -3],
#        [19,  0]])

# %%
C.T
# Out:
# array([[ 4,  8, -2, 19],
#        [-5, 12, -3,  0]])

# %% [markdown]
# Transposing scalars

# %%
s = np.array([5])

# %%
s.T
# Out:
# array([5])

# %% [markdown]
# Transposing vectors

# %%
x = np.array([1,2,3])
x
# Out:
# array([1, 2, 3])

# %%
x.T
# Out:
# array([1, 2, 3])

# %%
x.shape
# Out:
# (3,)

# %%
x_reshaped = x.reshape(1,3)
x_reshaped
# Out:
# array([[1, 2, 3]])

# %%
x_reshaped.T
# Out:
# array([[1],
#        [2],
#        [3]])

# %% [markdown]
# Dot product
#
# np.dot() returns the dot product or two objects

# %%
x = np.array([2,8,-4])
y = np.array([1,-7,3])

# %%
np.dot(x,y)
# Out:
# -66

# %%
u = np.array([0,2,5,8])
v = np.array([20, 3, 4,-1])

# %%
np.dot(u,v)
# Out:
# 18
