# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/The-Data-Analyst-Course-Complete-Data-Analyst-Bootcamp-2023/blob/main/iTunes_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
import json

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site + "?term=the+beatles&country=us"

requests.get(url)
# Out:
# <Response [200]>

# %%
r = requests.get(base_site, params = {"term": "the beatles", "country": "us"})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us'

# %% [markdown]
# Investigating the output and parameters

# %%
info = r.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "audiobook",
#             "artistId": 160778930,
#             "collectionId": 1439484338,
#             "artistName": "Bob Spitz",
#             "collectionName": "The Beatles (Abridged)",
#             "collectionCensoredName": "The Beatles (Abridged)",
#             "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#             "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#             "collectionPrice": 16.99,
#             "collectionExplicitness": "notExplicit",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(info['results'][0], indent=4))
# Out:
# {
#     "wrapperType": "audiobook",
#     "artistId": 160778930,
#     "collectionId": 1439484338,
#     "artistName": "Bob Spitz",
#     "collectionName": "The Beatles (Abridged)",
#     "collectionCensoredName": "The Beatles (Abridged)",
#     "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#     "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#     "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#     "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#     "collectionPrice": 16.99,
#     "collectionExplicitness": "notExplicit",
#     "trackCount": 1,
#     "country": "USA",
#     "currency": "USD",
#     "releaseDate": "2005-11-01T08:00:00Z",
#     "primaryGenreName": "Biographies & Memoirs",
# ...

# %%
info["resultCount"]
# Out:
# 50

# %%
r = requests.get(base_site, params = {"term": "the beatles", "country": "us", "limit": 200})
r.ok
# Out:
# True

# %%
r.json()["resultCount"]
# Out:
# 173

# %% [markdown]
# Structuring and Exporting the Data

# %%
import pandas as pd

# %%
songs_df = pd.DataFrame(info["results"])
songs_df
# Out:
#    wrapperType     artistId  collectionId  \
# 0    audiobook  160778930.0  1.439484e+09
# 1        track     157458.0  2.824953e+08
# 2    audiobook  511539599.0  5.115394e+08
# 3    audiobook  310801194.0  1.454534e+09
# 4    audiobook  125377525.0  1.892225e+08
# 5        track   27068619.0  3.907985e+08
# 6    audiobook    2065398.0  1.477982e+09
# 7    audiobook  434226404.0  1.648541e+09
# 8        track     329275.0  2.073154e+08
# 9        track     157458.0  2.847152e+08
# 10   audiobook  265867174.0  2.662416e+08
# 11       track     136975.0  1.441133e+09
# 12       track     136975.0  1.441133e+09
# 13       track  292320406.0  6.342229e+08
# 14       track  829356035.0  1.192835e+09
# 15       track     136975.0  1.441133e+09
# 16       track     136975.0  1.441133e+09
# 17       track     136975.0  1.441133e+09
# 18       track  315816847.0  6.968843e+08
# 19       track     136975.0  1.441133e+09
# 20       track     136975.0  1.441133e+09
# ...

# %%
songs_df.to_csv("songs_info.csv")

# %%
songs_df.to_excel("songs_info.xlsx")

# %% [markdown]
# Bergen

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site + "?term=bergen&country=tr"

requests.get(url)
# Out:
# <Response [200]>

# %%
r = requests.get(base_site, params = {"term": "bergen", "country": "tr"})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=bergen&country=tr'

# %%
info = r.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 9789051,
#             "collectionId": 1361973632,
#             "trackId": 1361974553,
#             "artistName": "Purple Haze",
#             "collectionName": "A State of Trance 2018 (Mixed By Armin van Buuren)",
#             "trackName": "Bergen",
#             "collectionCensoredName": "A State of Trance 2018 (Mixed By Armin van Buuren)",
#             "trackCensoredName": "Bergen",
#             "collectionArtistId": 17976294,
#             "collectionArtistName": "Armin van Buuren",
#             "collectionArtistViewUrl": "https://music.apple.com/tr/artist/armin-van-buuren/17976294?uo=4",
#             "artistViewUrl": "https://music.apple.com/tr/artist/purple-haze/9789051?uo=4",
#             "collectionViewUrl": "https://music.apple.com/tr/album/bergen/1361973632?i=1361974553&uo=4",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(info['results'][0], indent=4))
# Out:
# {
#     "wrapperType": "track",
#     "kind": "song",
#     "artistId": 9789051,
#     "collectionId": 1361973632,
#     "trackId": 1361974553,
#     "artistName": "Purple Haze",
#     "collectionName": "A State of Trance 2018 (Mixed By Armin van Buuren)",
#     "trackName": "Bergen",
#     "collectionCensoredName": "A State of Trance 2018 (Mixed By Armin van Buuren)",
#     "trackCensoredName": "Bergen",
#     "collectionArtistId": 17976294,
#     "collectionArtistName": "Armin van Buuren",
#     "collectionArtistViewUrl": "https://music.apple.com/tr/artist/armin-van-buuren/17976294?uo=4",
#     "artistViewUrl": "https://music.apple.com/tr/artist/purple-haze/9789051?uo=4",
#     "collectionViewUrl": "https://music.apple.com/tr/album/bergen/1361973632?i=1361974553&uo=4",
#     "trackViewUrl": "https://music.apple.com/tr/album/bergen/1361973632?i=1361974553&uo=4",
# ...

# %%
info["resultCount"]
# Out:
# 50

# %%
r = requests.get(base_site, params = {"term": "bergen", "country": "tr", "limit": 200})
r.ok
# Out:
# True

# %%
r.json()["resultCount"]
# Out:
# 187

# %%
songs_df = pd.DataFrame(info["results"])
songs_df
# Out:
#    wrapperType           kind      artistId  collectionId     trackId  \
# 0        track           song  9.789051e+06  1.361974e+09  1361974553
# 1        track           song  9.789051e+06  1.363612e+09  1363612408
# 2        track           song  3.342828e+08  1.523050e+09  1523049613
# 3        track           song  1.457220e+09  1.497299e+09  1497299412
# 4        track           song  1.438111e+09  1.438111e+09  1438110682
# 5        track           song  9.789051e+06  1.468584e+09  1468584200
# 6        track           song  9.789051e+06  1.468596e+09  1468595840
# 7        track           song  2.842551e+08  1.646421e+09  1646421072
# 8        track           song  9.789051e+06  1.468596e+09  1468595839
# 9        track           song  9.789051e+06  1.459406e+09  1459405951
# 10       track  feature-movie           NaN           NaN  1313649758
# 11       track           song  1.438111e+09  1.537460e+09  1537459804
# ...

# %%
songs_df.loc[songs_df["artistName"] == "Bergen"]
# Out:
#    wrapperType  kind     artistId  collectionId    trackId artistName  \
# 47       track  song  172296965.0   860597933.0  860597966     Bergen
#
#      collectionName     trackName collectionCensoredName trackCensoredName  \
# 47  Acıların Kadını  Sen Affetsen        Acıların Kadını      Sen Affetsen
#
#     ...  currency primaryGenreName isStreamable collectionHdPrice  \
# 47  ...       TRY              Pop         True               NaN
#
#    trackHdPrice contentAdvisoryRating shortDescription longDescription  \
# 47          NaN                   NaN              NaN             NaN
#
#    trackRentalPrice trackHdRentalPrice
# 47              NaN                NaN
#
# [1 rows x 41 columns]
